# %%
import json
import os
import requests

import rdflib as rl
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import numpy as np

# %%
r = requests.get('https://ndar.nih.gov/api/datadictionary/v2/datastructure')

# %%
ds_data = r.json()

# %%
ds_data[0]
# Out:
# {u'categories': [u'Questionnaire'],
#  u'dataType': u'Clinical Assessments',
#  u'publishDate': None,
#  u'shortName': u'grit01',
#  u'sources': [u'RDoC'],
#  u'status': u'Published',
#  u'title': u'12-Item Grit Scale'}

# %%
ds_names = [val['shortName'] for val in ds_data]
ds_titles = [val['title'] for val in ds_data]

# %%
ds_names[:10]
# Out:
# [u'grit01',
#  u'nepsy01',
#  u'ace_fammedhist01',
#  u'ace_subjmedhist01',
#  u'ace_physexam01',
#  u'adhdrs01',
#  u'adhdc01',
#  u'agre_ados1_200101',
#  u'agre_ados1_200102',
#  u'agre_ados2_200102']

# %%
def fetch_named_ds(name):
    named_json = '{0}.json'.format(name)
    if not os.path.exists(named_json):
        r = requests.get('https://ndar.nih.gov/api/datadictionary/v2/datastructure/{0}'.format(name))
        named_data = r.json()
        with open(named_json, 'wt') as fp:
            json.dump(named_data, fp)
    else:
        with open(named_json, 'rt') as fp:
            named_data = json.load(fp)
    info = []
    for element in named_data['dataElements']:
        info_el = []
        info_el.append(element['name'])
        info_el.append(element['description'])
        info_el.append(element['aliases'])
        info.append(info_el)
    return info

# %%
fetch_named_ds(ds_names[0])
# Out:
# [[u'subjectkey',
#   u'The NDAR Global Unique Identifier (GUID) for research subject',
#   []],
#  [u'src_subject_id', u"Subject ID how it's defined in lab/project", []],
#  [u'interview_date',
#   u'Date on which the interview/genetic test/sampling/imaging was completed. MM/DD/YYYY',
#   []],
#  [u'interview_age',
#   u'Age in months at the time of the interview/test/sampling/imaging.',
#   []],
#  [u'gender', u'Sex of the subject', []],
#  [u'grit1',
#   u'I have overcome setbacks to conquer an important challenge.',
#   []],
#  [u'grit2',
#   u'New ideas and projects sometimes distract me from previous ones.',
#   []],
#  [u'grit3', u'My interests change from year to year.', []],
#  [u'grit4', u"Setbacks don't discourage me.", []],
#  [u'grit5',
#   u'I have been obsessed with a certain idea or project for a short time but later lost interest.',
#   []],
#  [u'grit6', u'I am a hard worker.', []],
#  [u'grit7',
#   u'I often set a goal but later choose to pursue a different one.',
#   []],
#  [u'grit8',
#   u'I have difficulty maintaining my focus on projects that take more than a few months to complete.',
#   []],
#  [u'grit9', u'I finish whatever I begin.', []],
#  [u'grit10', u'I have achieved a goal that took years of work.', []],
#  [u'grit11', u'I become interested in new pursuits every few months.', []],
#  [u'grit12', u'I am diligent.', []],
#  [u'grit_total', u'Grit Total score', []],
#  [u'grit_ci', u'Consistency of interests', []],
#  [u'grit_pe', u'Perseverance of effort', []]]

# %%
all_info = []
for idx, name in enumerate(ds_names):
    val = dict(name=name)
    val['description'] = ds_titles[idx]
    val['info'] = fetch_named_ds(name)
    all_info.append(val)

# %%
def generate_graph(info):
    nda = rl.Namespace("https://ndar.nih.gov/api/datadictionary/v2/datastructure/")
    ex = rl.Namespace("https://example.org/")
    g = rl.ConjunctiveGraph()
    g.bind("nda", nda)
    g.bind("ex", ex)
    tokens = []
    for val in info:
        g.add((nda[val['name']], ex['description'], rl.Literal(val['description'])))
        tokens.append(val['description'])
        for item in val['info']:
            item_el = rl.URIRef(str(nda) + val['name'] + '/' + item[0])
            g.add((nda[val['name']], ex['hasItem'], item_el))
            g.add((item_el, ex['description'], rl.Literal(item[1])))
            g.add((item_el, ex['description'], rl.Literal(item[0])))
            tokens.append(item[0])
            tokens.append(item[1])
            for alias in item[2]:
                item_alias = rl.URIRef(str(nda) + val['name'] + '/' + alias)
                g.add((item_el, ex['isSameas'], item_alias))
                g.add((item_alias, ex['description'], rl.Literal(alias)))
                g.add((nda[val['name']], ex['hasItem'], item_alias))
                tokens.append(alias)
    return g, tokens

# %%
g, tokens = generate_graph(all_info[:10])

# %%
print(g.serialize(format='turtle'))
# Out:
# @prefix ex: <https://example.org/> .
# @prefix nda: <https://ndar.nih.gov/api/datadictionary/v2/datastructure/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# nda:ace_fammedhist01 ex:description "ACE Family Medical History" ;
#     ex:hasItem <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ad_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/adhd_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/adhd_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/adhd_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/adhd_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/adhd_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/anx_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/anx_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/anx_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/anx_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/anx_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asd_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/asp_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/bipd_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/bipd_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/bipd_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/bipd_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/bipd_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cblind_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/cerpal_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/comments_misc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/depr_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/depr_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/depr_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/depr_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/depr_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/downs_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/dsp_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/eatd_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/eatd_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/eatd_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/eatd_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/eatd_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/family_user_def_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_adhd>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_anxiety>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_bipolar>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_depression>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_devdelay>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_eatingdis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_fragilex>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_learndis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_ocd>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_schizophrenia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_selfinj>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_speechdelay>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/father_tuberscl>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/fx_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/fx_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/fx_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/fx_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/fx_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/gender>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/hearcor_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/heard_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/idmr_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/interview_age>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/interview_date>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_adhd>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_anxiety>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_bipolar>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_depression>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_devdelay>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_eatingdis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_fragilex>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_learndis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_ocd>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_schizophrenia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_selfinj>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_speechdelay>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/mother_tuberscl>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/nfi_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ocd_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ocd_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ocd_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ocd_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ocd_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/pddn_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_age1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_age2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_age3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_age4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_age5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_agebf>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_agebm>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_devdelay1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_devdelay2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_devdelay3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_devdelay4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_devdelay5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gender1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gender2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gender3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gender4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gender5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gradalbf>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_gradalbm>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_langdelay1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_langdelay2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_langdelay3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_langdelay4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_langdelay5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_learndis1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_learndis2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_learndis3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_learndis4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/ques_learndis5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/relationship>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/rts_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/schiz_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/schiz_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/schiz_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/schiz_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/schiz_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/seiz_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sibling_type1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sibling_type2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sibling_type3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sibling_type4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sibling_type5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sinjb_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sinjb_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sinjb_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sinjb_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/sinjb_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_father_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_mother_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_sibling1_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_sibling2_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_sibling3_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_sibling4_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_sibling5_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/src_subject_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_father>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_mother>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_sibling1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_sibling2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_sibling3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_sibling4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/subjectkey_sibling5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_fath>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_moth>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tours_sib5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tuberscl_sib1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tuberscl_sib2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tuberscl_sib3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tuberscl_sib4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_fammedhist01/tuberscl_sib5> .
#
# nda:ace_physexam01 ex:description "ACE Subject Physical Exam" ;
#     ex:hasItem <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_cardio_murmur>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_eyes_nystagmus>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_eyes_ptosis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_head_faciala>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_limb_jointlimitations>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_neck_scoliosis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_neck_webbed>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_neuro_involunmove>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_comments>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_hyperpig>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_hypopigmen>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_neurofib>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/GUID>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/abdomen_hepatom>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/cardio_murmur>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/child_hearingimp>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/child_visionimp>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/comments_misc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/cran_nerv>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/ear_ab_type>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/eye_correct>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/eye_mov>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/eyes_nystagmus>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/eyes_ptosis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/eyes_strabismus>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/facial_dysmorp>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/gait_atax>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/gender>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/genit_exam>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/genit_exam_spec>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/head_circum>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/head_faciala>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/hear_corr_type>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/height_met>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/hypertonia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/hypotonia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/interview_age>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/interview_date>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/jaw_ab>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/limb_abnor>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/limb_abnor_det>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/limb_joint_loos>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/limb_jointlimitations>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/medprob_ear>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/muscle_streng>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/muscle_streng_det>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/neck_pect>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/neck_scoliosis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/neck_webbed>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/neuro_involunmove>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/rev_mouthcleftlip>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/sens_exam>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/skin_abnorm>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/skin_freck>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/skin_hyperpig>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/skin_hypopigmen>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/skin_neurofib>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/src_subject_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/subjectkey>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/weight_met> .
#
# nda:ace_subjmedhist01 ex:description "ACE Subject Medical History" ;
#     ex:hasItem <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/ad016>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/age_3word>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/aut_diag>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/birth_weight_lbs>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/cfmh_othr_ocd>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/comments_misc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/current_lang>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/data_derived>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/devel_concern>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/diag_ageatdiag>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/diag_aofc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/diag_diagnosismadeby>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/ds_med>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/earlydev_walk>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/fhxcp>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/full_term>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/gastro_spec_diet>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/gen_dis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/gen_dis_conf>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/gender>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/hear_loss>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/hist_trauma>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/info_gest>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/interview_age>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/interview_date>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/ldnb_hosptotalbabyday>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/ldnb_lgthin>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/otc_med>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_adhd>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_anxiety>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_bipolar>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_depression>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_devdelay>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_eatingdis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_eatingdis_type>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_hearingcor>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_schizophrenia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/othmem_selfinj>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/preg_complic>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/preg_dxdrug>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_cardiocyanosis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_cardiomalfunc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_earpetube>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_earrecuotitis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_earrecuotitisage>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_earrecuotitisyear>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_eartest>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_eartestages>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_eartestresult>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endodiabetes>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endodiabetestype>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endohyperthyroidism>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endohypoglycemia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endohypothyroidism>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endoprecocious>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_endoprecociousage>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_gastrodysphagia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_gastroother>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_gastroreflux>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_gastrorefluxmed>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headencephalitis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headencephalitisage>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headencephalitisorg>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headfebseiz>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headfebseizages>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headimagestudy>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headimagestudyresult>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headimagestudytype>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headmeningitis>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headmeningitisage>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headmeningitisorg>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headseizure>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headseizurecontrol>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_headseizureonset>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_hemanemia>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_hembleeddisorder>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_immunocellimmunedef>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_immunoenvallergy>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_immunoigdeficiency>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_immunoimmunization>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_immunomedallergy>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_immunorecurinfection>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_lung>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_mouthcleftlip>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_mouthcleftpalate>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_neckspinalab>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_pulasthma>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_pulbreathab>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_rythm>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_skinabcesses>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_skinbirthmark>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_skineczema>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rev_teethdentalab>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rx_behav>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/rx_phys>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/school_perf>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/sleep_pat>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/src_subject_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/subjectkey>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/touret>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/verb_words>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_subjmedhist01/vis_blind> .
#
# nda:adhdc01 ex:description "ADHD Symptom Checklist" ;
#     ex:hasItem <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/actthink>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/avoidmtl>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/blurts>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/dayscons>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/diffattn>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/difffoll>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/difforgn>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/diffplay>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/diffseat>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/diffwait>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/easdistr>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/fidgety>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/forgetof>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/gender>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/hyperact>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/hyperactiv>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/interrup>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/interview_age>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/interview_date>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/losethgs>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/nodetail>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/nolisten>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/onthego>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/shiftact>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/site>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/site_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/siteid>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/src_subject_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/stepid>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/subjectkey>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/talkexce>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/visit> .
#
# nda:adhdrs01 ex:description "ADHD Rating Scale" ;
#     ex:hasItem <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/age_ons>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/ageyears>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/asd_child_id>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/asd_respnum>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/child_sex>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/complete_date>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/gender>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/guid>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/interview_age>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/interview_date>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_1>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_10>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_10_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_11>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_11_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_12>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_12_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_13>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_13_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_14>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_14_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_15>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_15_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_16>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_16_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_17>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_17_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_18>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_18_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_19>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_1_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_2>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_20>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_21>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_22>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_23>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_24>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_25>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_26>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_27>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_2_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_3>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_3_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_4>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_4_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_5>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_5_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_6>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_6_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_7>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_7_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_8>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_8_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_9>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_9_rc>,
#         <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_hyp_rs>,
# ...
#         "memface_sc8" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memface_sc9> ex:description "Memory for Faces 9 score",
#         "memface_sc9" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc1> ex:description "Memory for Faces Delayed 1 score",
#         "memfad_sc1" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc10> ex:description "Memory for Faces Delayed 10 score",
#         "memfad_sc10" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc11> ex:description "Memory for Faces Delayed 11 score",
#         "memfad_sc11" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc12> ex:description "Memory for Faces Delayed 12 score",
#         "memfad_sc12" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc13> ex:description "Memory for Faces Delayed 13 score",
#         "memfad_sc13" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc14> ex:description "Memory for Faces Delayed 14 score",
#         "memfad_sc14" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc15> ex:description "Memory for Faces Delayed 15 score",
#         "memfad_sc15" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc16> ex:description "Memory for Faces Delayed 16 score",
#         "memfad_sc16" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc2> ex:description "Memory for Faces Delayed 2 score",
#         "memfad_sc2" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc3> ex:description "Memory for Faces Delayed 3 score",
#         "memfad_sc3" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc4> ex:description "Memory for Faces Delayed 4 score",
#         "memfad_sc4" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc5> ex:description "Memory for Faces Delayed 5 score",
#         "memfad_sc5" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc6> ex:description "Memory for Faces Delayed 6 score",
#         "memfad_sc6" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc7> ex:description "Memory for Faces Delayed 7 score",
#         "memfad_sc7" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc8> ex:description "Memory for Faces Delayed 8 score",
#         "memfad_sc8" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/memfad_sc9> ex:description "Memory for Faces Delayed 9 score",
#         "memfad_sc9" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/mf_scaled> ex:description "MF  Scaled Score",
#         "mf_scaled" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/mf_totscore> ex:description "MF Total Score",
#         "mf_totscore" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/mfd_scaled> ex:description "MFD  Scaled Score",
#         "mfd_scaled" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/mfd_totscore> ex:description "MFD Total Score",
#         "mfd_totscore" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/mfvsmfd_scaled> ex:description "MF vs. MFD Contrast Scaled score",
#         "mfvsmfd_scaled" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/n_neuterperc> ex:description "Neutral Errors Percentile Rank",
#         "n_neuterperc" ;
#     ex:isSameas <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/neutral_pr> .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/n_totneuter> ex:description "Total Neutral (N) Errors",
#         "n_totneuter" ;
#     ex:isSameas <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/neutralerrors> .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/pencgrip> ex:description "Behavioral Observations Pencil Grip",
#         "pencgrip" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/perc_ss> ex:description "Behavioral Observations Percent of Standartized Sample",
#         "perc_ss" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/s_saderperc> ex:description "Sad Errors Percentile Rank",
#         "s_saderperc" ;
#     ex:isSameas <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/sad_pr> .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/s_totsader> ex:description "Total Sad (S) Errors",
#         "s_totsader" ;
#     ex:isSameas <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/saderrors> .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/src_subject_id> ex:description "Subject ID how it's defined in lab/project",
#         "src_subject_id" ;
#     ex:isSameas <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/id> .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/stoptime> ex:description "Stop time",
#         "stoptime" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/subjectkey> ex:description "The NDAR Global Unique Identifier (GUID) for research subject",
#         "subjectkey" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/test_reason> ex:description "Reason for Testing",
#         "test_reason" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc1> ex:description "Theory of Mind 1 score",
#         "theormind_sc1" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc10> ex:description "Theory of Mind 10 score",
#         "theormind_sc10" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc11> ex:description "Theory of Mind 11 score",
#         "theormind_sc11" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc12> ex:description "Theory of Mind 12 score",
#         "theormind_sc12" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc13> ex:description "Theory of Mind 13 score",
#         "theormind_sc13" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc14> ex:description "Theory of Mind 14 score",
#         "theormind_sc14" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc15> ex:description "Theory of Mind 15 score",
#         "theormind_sc15" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc16> ex:description "Theory of Mind 16 Contextual task score",
#         "theormind_sc16" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc17> ex:description "Theory of Mind 17 Contextual task score",
#         "theormind_sc17" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc18> ex:description "Theory of Mind 18 Contextual task score",
#         "theormind_sc18" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc19> ex:description "Theory of Mind 19 Contextual task score",
#         "theormind_sc19" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc2> ex:description "Theory of Mind 2 score",
#         "theormind_sc2" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc21> ex:description "Theory of Mind 21 Contextual task score",
#         "theormind_sc21" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc3> ex:description "Theory of Mind 3 score",
#         "theormind_sc3" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc4> ex:description "Theory of Mind 4 score",
#         "theormind_sc4" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc5> ex:description "Theory of Mind 5 score",
#         "theormind_sc5" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc6> ex:description "Theory of Mind 6 score",
#         "theormind_sc6" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc7> ex:description "Theory of Mind 7 score",
#         "theormind_sc7" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc8> ex:description "Theory of Mind 8 score",
#         "theormind_sc8" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/theormind_sc9> ex:description "Theory of Mind 9 score",
#         "theormind_sc9" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/tm_context> ex:description "TM Contextual",
#         "tm_context" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/tm_scaledperc> ex:description "TM Scaled Score/Percentile Rank",
#         "tm_scaledperc" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/tm_totscore> ex:description "TM Total Score",
#         "tm_totscore" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/tm_verbalperc> ex:description "TM Percentile Rank",
#         "tm_verbalperc" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/tm_verbalscore> ex:description "TM Verbal Score",
#         "tm_verbalscore" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/visprec_ct1> ex:description "Visuomotor Precision. Car. Completion time",
#         "visprec_ct1" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/visprec_ct2> ex:description "Visuomotor Precision. Motorcycle. Completion time",
#         "visprec_ct2" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/visprec_er1> ex:description "Visuomotor Precision. Car. Errors",
#         "visprec_er1" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/visprec_er2> ex:description "Visuomotor Precision. Motorcycle. Errors",
#         "visprec_er2" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/visprec_pt1> ex:description "Visuomotor Precision. Car. Pencil Lifts",
#         "visprec_pt1" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/visprec_pt2> ex:description "Visuomotor Precision. Motorcycle. Pencil Lifts",
#         "visprec_pt2" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/vp_pltot> ex:description "VP Pencil Lift Total",
#         "vp_pltot" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/vp_pltotperc> ex:description "VP Pencil Lift Percentile Rank",
#         "vp_pltotperc" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/vp_scaled> ex:description "VP Total Completion Time Scaled Score",
#         "vp_scaled" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/vp_toter> ex:description "VP Total errors",
#         "vp_toter" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/vp_toterperc> ex:description "VP Total Errors Percentile Rank",
#         "vp_toterperc" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/vp_tottime> ex:description "\"VP Total Completion Time, seconds\"",
#         "vp_tottime" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_cardio_murmur> ex:description "Charge_physicalexam_cardio_murmur" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_eyes_nystagmus> ex:description "Charge_physicalexam_eyes_nystagmus" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_eyes_ptosis> ex:description "Charge_physicalexam_eyes_ptosis" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_head_faciala> ex:description "Charge_physicalexam_head_faciala" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_limb_jointlimitations> ex:description "Charge_physicalexam_limb_jointlimitations" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_neck_scoliosis> ex:description "Charge_physicalexam_neck_scoliosis" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_neck_webbed> ex:description "Charge_physicalexam_neck_webbed" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_neuro_involunmove> ex:description "Charge_physicalexam_neuro_involunmove" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_comments> ex:description "Charge_physicalexam_skin_comments" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_hyperpig> ex:description "Charge_physicalexam_skin_hyperpig" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_hypopigmen> ex:description "Charge_physicalexam_skin_hypopigmen" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/Charge_physicalexam_skin_neurofib> ex:description "Charge_physicalexam_skin_neurofib" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/ace_physexam01/GUID> ex:description "GUID" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/hyperact> ex:description "hyperact" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/site_id> ex:description "site_id" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/siteid> ex:description "siteid" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdc01/stepid> ex:description "stepid" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/ageyears> ex:description "ageyears" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/asd_child_id> ex:description "asd_child_id" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/asd_respnum> ex:description "asd_respnum" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/child_sex> ex:description "child_sex" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/complete_date> ex:description "complete_date" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/guid> ex:description "guid" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/adhdrs01/p_c_adhdrs_onset> ex:description "p_c_adhdrs_onset" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/angry_pr> ex:description "angry_pr" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/angryerrors> ex:description "angryerrors" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/ar_ss> ex:description "ar_ss" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/artotal> ex:description "artotal" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/date> ex:description "date" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/disgust_pr> ex:description "disgust_pr" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/disgusterrors> ex:description "disgusterrors" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/fear_pr> ex:description "fear_pr" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/fearerrors> ex:description "fearerrors" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/happy_pr> ex:description "happy_pr" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/happyerrors> ex:description "happyerrors" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/id> ex:description "id" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/neutral_pr> ex:description "neutral_pr" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/neutralerrors> ex:description "neutralerrors" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/sad_pr> ex:description "sad_pr" .
#
# <https://ndar.nih.gov/api/datadictionary/v2/datastructure/nepsy01/saderrors> ex:description "saderrors" .

# %%
query = """
PREFIX ex: <https://example.org/>

SELECT ?assessment where
{
    FILTER (EXISTS { ?assessment ex:description "%s" } ||
            EXISTS { ?assessment ex:hasItem/ex:description "%s" }) .
}

"""

def get_parent(g, val):
    query_str = query % (val, val)
    #print("A" + query_str + "B")
    return g.query(query_str)

# %%
process.extract("fath", np.unique(tokens).tolist(), limit=10)
# Out:
# [(u'"Asperger Syndrome, father"', 90),
#  (u'"Autism Disorder, father"', 90),
#  (u'"Autism Spectrum Disorder, father"', 90),
#  (u'"Cerebral Palsy, father"', 90),
#  (u'"Congenital Blindness, father"', 90),
#  (u'"Disrupted sleep patterns, father"', 90),
#  (u'"Down Syndrome, father"', 90),
#  (u'"Neurofibromatosis I, father"', 90),
#  (u'"PDD-NOS, father"', 90),
#  (u'"Rett Syndrome, father"', 90)]

# %%
process.extract("fibromatosis", np.unique(tokens).tolist(), limit=10)
# Out:
# [(u'"Neurofibromatosis I, father"', 90),
#  (u'"Neurofibromatosis I, mother"', 90),
#  (u'"Neurofibromatosis I, sibling 1"', 90),
#  (u'"Neurofibromatosis I, sibling 2"', 90),
#  (u'"Neurofibromatosis I, sibling 3"', 90),
#  (u'"Neurofibromatosis I, sibling 4"', 90),
#  (u'"Neurofibromatosis I, sibling 5"', 90),
#  (u'Ptosis', 75),
#  (u'oman', 68),
#  (u'Are there neurofibromas (bumps under the skin, sometimes with a bluish tinge)?',
#   64)]

# %%
process.extract("fibromatosis", np.unique(tokens).tolist(), limit=10)

# %%
matches = process.extract("subject", np.unique(tokens).tolist(), limit=10)
print(matches)
for match in matches:
    pass
    #print(match, get_parent(g, match[0]).bindings)
# Out:
# [(u'ACE Subject Medical History', 90), (u'ACE Subject Physical Exam', 90), (u'Does subject have a special diet?', 90), (u'Sex of the subject', 90), (u"Subject ID how it's defined in lab/project", 90), (u'src_subject_id', 90), (u'subjectkey_father', 90), (u'subjectkey_mother', 90), (u'subjectkey_sibling1', 90), (u'subjectkey_sibling2', 90)]
